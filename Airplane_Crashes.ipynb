# %%
#import libraries libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, datetime,timedelta 


df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %%
df.sample(5).T
# Out:
#                                               4001
# Date                                    03/18/1991  \
# Time                                           NaN
# Location                     Treasure Cay, Bahamas
# Operator      Broward Aviation Services - Air Taxi
# Flight #                                       NaN
# Route                                          NaN
# Type                                   Cessna 402C
# Registration                                N5785C
# cn/In                                     402C0043
# Aboard                                         5.0
# Fatalities                                     5.0
# Ground                                         0.0
# Summary                 Crashed while on approach.
#
#                                                            5061
# Date                                                 08/16/2005  \
# Time                                                      03:30
# Location                           Near La Cucharita, Venezuela
# Operator                                 West Caribbean Airways
# Flight #                                                    NaN
# Route                  Panama City - Fort de France, Martinique
# Type                                    McDonnell Douglas MD-82
# Registration                                           HK-4374X
# cn/In                                                49484/1315
# Aboard                                                    160.0
# Fatalities                                                160.0
# Ground                                                      0.0
# Summary       While en route, the crew reported engine troub...
#
#                                                            1779
# Date                                                 06/03/1962  \
# Time                                                      12:35
# Location                Villeneuve-le-Roi, Val-de-Marne, France
# Operator                                             Air France
# Flight #                                                    NaN
# Route                                     Paris - New York City
# Type                                           Boeing B-707-328
# Registration                                             F-BHSM
# cn/In                                                 17920/159
# Aboard                                                    132.0
# Fatalities                                                130.0
# Ground                                                      0.0
# Summary       During takeoff from Orly Airport, the nose ros...
#
#                                                            3602
# Date                                                 01/29/1986  \
# Time                                                        NaN
# Location                                    Las Lomitas, Mexico
# Operator                                         Aerocalifornia
# Flight #                                                    NaN
# Route                           Villa Constitucion - Los Mochis
# Type                                          Douglas DC-3A-178
# Registration                                             XA-IOR
# cn/In                                                      1547
# Aboard                                                     21.0
# Fatalities                                                 21.0
# Ground                                                      0.0
# Summary       The plane tried to land at Los Mochis but had ...
#
#                                                            2833
# Date                                                 08/03/1975
# Time                                                      04:30
# Location                                 Near Immouzer, Morocco
# Operator                          Alia Royal Jordanian Airlines
# Flight #                                                    NaN
# Route                                            Paris - Agadir
# Type                                          Boeing B-707-321C
# Registration                                             JY-AEE
# cn/In                                                 18767/376
# Aboard                                                    188.0
# Fatalities                                                188.0
# Ground                                                      0.0
# Summary       The aircraft was on approach when the right wi...

# %%
df.shape
# Out:
# (5268, 13)

# %% [markdown]
# # Dataset consist of 5268 observations (crashes) and 13 features.

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %% [markdown]
# # Aircraft Crash Information:
#
# - **Date:** date the crash
# - **Time:** time the crash
# - **Location:** City, Country
# - **Operator:** Airline Name (Royal air maroc,rayanair,.....)
# - **Flight #:** Flight Number
# - **Route:** Departure - Destination
# - **Type:** Aircraft Type (Boeing 737,Airbus A320,....)
# - **Registration:** Aircraft Registration (An aircraft registration is a code unique to a single aircraft)
# - **cn/In:** Construction/Serial Number(is a unique identifier assigned to each individual aircraft during its manufacturing process)
# - **Aboard:** Number of People Aboard
# - **Fatalities:** Number of Fatalities
# - **Ground:** individuals who are not on board the aircraft but are located in the vicinity of the crash site
# - **Summary:** Brief Summary of the Case

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3561 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
df.iloc[5265]
# Out:
# Date                                                   06/01/2009
# Time                                                        00:15
# Location        AtlantiOcean, 570 miles northeast of Natal, Br...
# Operator                                               Air France
# Flight #                                                      447
# Route                                      Rio de Janeiro - Paris
# Type                                              Airbus A330-203
# Registration                                               F-GZCP
# cn/In                                                         660
# Aboard                                                      228.0
# Fatalities                                                  228.0
# Ground                                                        0.0
# Summary         The Airbus went missing over the AtlantiOcean ...
# Name: 5265, dtype: object

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %%
df['Time'] = df['Time'].replace(np.nan, '00:00')
df['Time'] = df['Time'].str.replace('c: ', '')
df['Time'] = df['Time'].str.replace('c:', '')
df['Time'] = df['Time'].str.replace('c', '')
df['Time'] = df['Time'].str.replace('12\'20', '12:20')
df['Time'] = df['Time'].str.replace('18.40', '18:40')
df['Time'] = df['Time'].str.replace('0943', '09:43')
df['Time'] = df['Time'].str.replace('22\'08', '22:08')
df['Time'] = df['Time'].str.replace('114:20', '00:00') 

# Combine 'Date' and 'Time' columns in DateTime

df['DateTime'] = df['Date'] + ' ' + df['Time']

# Convert 'DateTime' to datetime type

def to_date(x):
    return datetime.strptime(x, '%m/%d/%Y %H:%M')

df['DateTime'] = df['DateTime'].apply(to_date)

# Convert 'Operator' column to uppercase duplicate values 

df['Operator'] = df['Operator'].str.upper()
#remove date and time
df = df.drop('Date',axis=1)
df = df.drop('Time',axis=1)

# %%
df = df.drop('Registration',axis=1)
df = df.drop('Flight #',axis=1) 
df = df.drop('cn/In',axis=1)

# %%
split_location = df['Location'].str.split(', ', expand=True)
df['City'] = split_location[0]
df['Country'] = split_location[1]
df = df.drop('Location',axis=1)

# %%
df['Company'] = df['Type'].str.extract('([A-Za-z]+)') #manufacturer aircraft

# %%
df.sample()
# Out:
#                                     Operator
# 4774  MILITARY - FLORIDA ARMY NATIONAL GUARD  \
#
#                                                   Route       Type  Aboard
# 4774  Fort Walton Beach, Fl - Oceana Naval Air Stati...  Short 360    21.0  \
#
#       Fatalities  Ground                                            Summary
# 4774        21.0     0.0  The plane was on a flight from Florida to Ocea...  \
#
#                 DateTime      City  Country Company
# 4774 2001-03-03 09:55:00  Unadilla  Georgia   Short

# %%
df.isnull().sum()
# Out:
# Operator        18
# Route         1707
# Type            27
# Aboard          22
# Fatalities      12
# Ground          22
# Summary        390
# DateTime         0
# City            20
# Country        218
# Company         27
# dtype: int64

# %%
'''
operator_counts = df['Operator']
for i in operator_counts:
    print(i)
    
    
'''
# Out:
# "\noperator_counts = df['Operator']\nfor i in operator_counts:\n    print(i)\n    \n    \n"

# %%
df['Operator'].fillna('', inplace=True)

# Count occurrences of 'MILITARY SERVICE MAIL TRANSPORT EXPRESS' in 'Operator' column
air_force_count = df[df['Operator'].str.contains('AIR FORCE', case=False)]['Operator'].count()

service_count  = df[df['Operator'].str.contains('SERVICE', case=False)]['Operator'].count()

mail_count  = df[df['Operator'].str.contains('MAIL', case=False)]['Operator'].count()

express_count  = df[df['Operator'].str.contains('TRANSPORT', case=False)]['Operator'].count()

tranpor_count  = df[df['Operator'].str.contains('EXPRESS', case=False)]['Operator'].count()

military_count = df[df['Operator'].str.contains('MILITARY', case=False)]['Operator'].count()

# Display the count
print("Number of operators containing 'Air force':", air_force_count)
print("Number of operators containing 'MILLITARY':", military_count)
print("Number of operators containing 'SERVICE':", service_count)
print("Number of operators containing 'MAIL :", mail_count)
print("Number of operators containing 'TRANSPORT':", tranpor_count)
print("Number of operators containing 'EXPRESS':", express_count)
# Out:
# Number of operators containing 'Air force': 605
# Number of operators containing 'MILLITARY': 781
# Number of operators containing 'SERVICE': 250
# Number of operators containing 'MAIL : 36
# Number of operators containing 'TRANSPORT': 58
# Number of operators containing 'EXPRESS': 153

# %%
# Define conditions for flight type
ope_conditions = [
    df['Operator'].str.contains('MAIL|EXPRESS|TRANSPORT|SERVICE', case=False, regex=True),
    df['Operator'].str.contains('PRIVATE', case=False),
    df['Operator'].str.contains('AIR FORCE|MILITARY', case=False, regex=True)
]

# Define corresponding values for flight type
flight_type_values = ['cargo', 'private', 'military']

# Create the 'Flight Type' column based on the conditions
df['Flight Type'] = np.select(ope_conditions, flight_type_values, default='passenger')

# Display the updated DataFrame
df.head()
# Out:
#                  Operator          Route                    Type  Aboard
# 0    MILITARY - U.S. ARMY  Demonstration        Wright Flyer III     2.0  \
# 1    MILITARY - U.S. NAVY    Test flight               Dirigible     5.0
# 2                 PRIVATE            NaN        Curtiss seaplane     1.0
# 3  MILITARY - GERMAN NAVY            NaN  Zeppelin L-1 (airship)    20.0
# 4  MILITARY - GERMAN NAVY            NaN  Zeppelin L-2 (airship)    30.0
#
#    Fatalities  Ground                                            Summary
# 0         1.0     0.0  During a demonstration flight, a U.S. Army fly...  \
# 1         5.0     0.0  First U.S. dirigible Akron exploded just offsh...
# 2         1.0     0.0  The first fatal airplane accident in Canada oc...
# 3        14.0     0.0  The airship flew into a thunderstorm and encou...
# 4        30.0     0.0  Hydrogen gas which was being vented was sucked...
#
#              DateTime                City           Country    Company
# 0 1908-09-17 17:18:00           Fort Myer          Virginia     Wright  \
# 1 1912-07-12 06:30:00         AtlantiCity        New Jersey  Dirigible
# 2 1913-08-06 00:00:00            Victoria  British Columbia    Curtiss
# 3 1913-09-09 18:30:00  Over the North Sea              None   Zeppelin
# 4 1913-10-17 10:30:00   Near Johannisthal           Germany   Zeppelin
#
#   Flight Type
# 0    military
# 1    military
# 2     private
# 3    military
# 4    military

# %%
df.sample(5).T
# Out:
#                                                           2067
# Operator                                       AEROVIAS HALCON  \
# Route                             Rio Gallegos -  Buenos Aires
# Type                                        Curtiss C-46F-1-CU
# Aboard                                                    16.0
# Fatalities                                                 1.0
# Ground                                                     0.0
# Summary      Ditched in the ocean after running out of fuel...
# DateTime                                   1966-08-17 18:30:00
# City                                             Puertos Lobos
# Country                                              Argentina
# Company                                                Curtiss
# Flight Type                                          passenger
#
#                                                           3142
# Operator                           MILITARY - INDIAN AIR FORCE  \
# Route                                                      NaN
# Type                              Hindustan Aeronautics 748-2M
# Aboard                                                    27.0
# Fatalities                                                27.0
# Ground                                                     0.0
# Summary      Crashed into a 16,000 ft. mountain 10 minutes ...
# DateTime                                   1979-06-07 11:00:00
# City                                                  Near Leh
# Country                                                  India
# Company                                              Hindustan
# Flight Type                                           military
#
#                                                           5044
# Operator                                WEST CARIBBEAN AIRWAYS  \
# Route                              Old Providence - San Andres
# Type                                              Let-410UVP-E
# Aboard                                                    14.0
# Fatalities                                                 8.0
# Ground                                                     0.0
# Summary      The small airliner crashed while taking off fr...
# DateTime                                   2005-03-26 10:15:00
# City                                                El Embrujo
# Country                                     Providencia Island
# Company                                                    Let
# Flight Type                                          passenger
#
#                                                           5041
# Operator                                              LOGANAIR  \
# Route                                    Glasgow - Campbeltown
# Type                  Pilatus-Britten Norman BN-2B-26 Islander
# Aboard                                                     2.0
# Fatalities                                                 2.0
# Ground                                                     0.0
# Summary      While on final approach, the air ambulance cra...
# DateTime                                   2005-03-15 00:15:00
# City                                           Off Campbeltown
# Country                                         United Kingdom
# Company                                                Pilatus
# Flight Type                                          passenger
#
#                                                           4063
# Operator                                   TARTARSTAN AIRLINES
# Route                                 Nizhnevartovsk - Bugulma
# Type                                             Antonov AN-24
# Aboard                                                    41.0
# Fatalities                                                41.0
# Ground                                                     0.0
# Summary      While on approach to Bugulma, the plane yawed ...
# DateTime                                   1991-11-26 05:02:00
# City                                              Near Bugulma
# Country                                                 Russia
# Company                                                Antonov
# Flight Type                                          passenger

# %%
new_column_order = ['DateTime', 'City', 'Country', 'Operator', 'Type', 'Company',
                    'Route', 'Aboard', 'Fatalities', 'Ground', 'Flight Type', 'Summary']
df = df[new_column_order]

# %%
df.sample(3).T
# Out:
#                             328
# DateTime     1934-06-22 00:00:00  \
# City              Chausseehausen
# Country                  Germany
# Operator      DEUTSCHE LUFTHANSA
# Type              Dornier Merkur
# Company                  Dornier
# Route                        NaN
# Aboard                       7.0
# Fatalities                   1.0
# Ground                       0.0
# Flight Type            passenger
# Summary         Weather related.
#
#                                                           1847
# DateTime                                   1963-05-03 13:27:00  \
# City                                                 Near Buca
# Country                                               Cameroon
# Operator                                           AIR AFRIQUE
# Type                                             Douglas DC-6B
# Company                                                Douglas
# Route                                           Douala - Lagos
# Aboard                                                    55.0
# Fatalities                                                55.0
# Ground                                                     0.0
# Flight Type                                          passenger
# Summary      The aircraft flew into a mountain at 6,500 ft....
#
#                                                           4806
# DateTime                                   2001-09-15 00:00:00
# City                                            Belo Horizonte
# Country                                                 Brazil
# Operator                                          TAM (BRAZIL)
# Type                                                Fokker 100
# Company                                                 Fokker
# Route                                      Recife  - Sao Paulo
# Aboard                                                    82.0
# Fatalities                                                 1.0
# Ground                                                     0.0
# Flight Type                                          passenger
# Summary      While the aircraft was over Belo Horizonte, th...

# %%
df.columns
# Out:
# Index(['DateTime', 'City', 'Country', 'Operator', 'Type', 'Company', 'Route',
#        'Aboard', 'Fatalities', 'Ground', 'Flight Type', 'Summary'],
#       dtype='object')

# %%
df.to_csv('Airplane_Crashes_V2.csv', index=False)
