# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, datetime,timedelta 
import calendar


df = pd.read_csv('Airplane_Crashes_and_Fatalities_Since_1908.csv')
df.shape
# Out:
# (5268, 13)

# %%
df.head()
# Out:
#          Date   Time                            Location
# 0  09/17/1908  17:18                 Fort Myer, Virginia  \
# 1  07/12/1912  06:30             AtlantiCity, New Jersey
# 2  08/06/1913    NaN  Victoria, British Columbia, Canada
# 3  09/09/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III  \
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground
# 0          NaN     1     2.0         1.0     0.0  \
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight #', 'Route', 'Type',
#        'Registration', 'cn/In', 'Aboard', 'Fatalities', 'Ground', 'Summary'],
#       dtype='object')

# %% [markdown]
# # Aircraft Crash Information:
#
# - **Date:** date the crash
# - **Time:** time the crash
# - **Location:** City, Country
# - **Operator:** Airline Name (Royal air maroc,rayanair,.....)
# - **Flight #:** Flight Number
# - **Route:** Departure - Destination
# - **Type:** Aircraft Type (Boeing 737,Airbus A320,....)
# - **Registration:** Aircraft Registration (An aircraft registration is a code unique to a single aircraft)
# - **cn/In:** Construction/Serial Number(is a unique identifier assigned to each individual aircraft during its manufacturing process)
# - **Aboard:** Number of People Aboard
# - **Fatalities:** Number of Fatalities
# - **Ground:** individuals who are not on board the aircraft but are located in the vicinity of the crash site
# - **Summary:** Brief Summary of the Case

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          5268 non-null   object
#  1   Time          3049 non-null   object
#  2   Location      5248 non-null   object
#  3   Operator      5250 non-null   object
#  4   Flight #      1069 non-null   object
#  5   Route         3561 non-null   object
#  6   Type          5241 non-null   object
#  7   Registration  4933 non-null   object
#  8   cn/In         4040 non-null   object
#  9   Aboard        5246 non-null   float64
#  10  Fatalities    5256 non-null   float64
#  11  Ground        5246 non-null   float64
#  12  Summary       4878 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 535.2+ KB

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1707
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %% [markdown]
# # Combine 'Date' and 'Time' columns in DateTime

# %%
df['Time'] = df['Time'].replace(np.nan, '00:00')
df['Time'] = df['Time'].str.replace('c: ', '')
df['Time'] = df['Time'].str.replace('c:', '')
df['Time'] = df['Time'].str.replace('c', '')
df['Time'] = df['Time'].str.replace('12\'20', '12:20')
df['Time'] = df['Time'].str.replace('18.40', '18:40')
df['Time'] = df['Time'].str.replace('0943', '09:43')
df['Time'] = df['Time'].str.replace('22\'08', '22:08')
df['Time'] = df['Time'].str.replace('114:20', '00:00') 

# Combine 'Date' and 'Time' columns in DateTime

df['DateTime'] = df['Date'] + ' ' + df['Time']

# Convert 'DateTime' to datetime type

def to_date(x):
    return datetime.strptime(x, '%m/%d/%Y %H:%M')

df['DateTime'] = df['DateTime'].apply(to_date)

# Convert 'Operator' column to uppercase duplicate values 

#remove Date and Time
df = df.drop('Date',axis=1)
df = df.drop('Time',axis=1)

# %%
df.sample(2).T
# Out:
#                                                            4808
# Location                             Decatur Island, Washington  \
# Operator                       Aeronautical Services - Air Taxi
# Flight #                                                    NaN
# Route                           Decatur Island, WAAnacortez, WA
# Type                                                Cessna 172N
# Registration                                             N733SW
# cn/In                                                  17268521
# Aboard                                                      3.0
# Fatalities                                                  3.0
# Ground                                                      0.0
# Summary       Witnesses to the accident reported that shortl...
# DateTime                                    2001-10-03 13:38:00
#
#                                                            938
# Location                                       Shannon, Ireland
# Operator                             Pan American World Airways
# Flight #                                                   1-10
# Route                                         Belgium - Shannon
# Type                            Lockheed L-049-46 Constellation
# Registration                                           NC-88858
# cn/In                                                      2058
# Aboard                                                     31.0
# Fatalities                                                 30.0
# Ground                                                      0.0
# Summary       While executing a second instrument approach a...
# DateTime                                    1948-04-15 02:35:00

# %%
df = df.drop(['Registration', 'Flight #', 'cn/In'], axis=1)

# %%
df['Year'] = df['DateTime'].dt.year
df['Month'] = df['DateTime'].dt.month
def number_to_month(num):
    return calendar.month_name[num]
df['Day'] = df['DateTime'].dt.day_name()

# %%
df['Location'].nunique()
# Out:
# 4303

# %%
df['Location'].value_counts()
# Out:
# Location
# Sao Paulo, Brazil                    15
# Moscow, Russia                       15
# Rio de Janeiro, Brazil               14
# Anchorage, Alaska                    13
# Manila, Philippines                  13
#                                      ..
# Near Charana, Bolivia                 1
# Monte Matto, Italy                    1
# Misaki Mountain, Japan                1
# Angelholm, Sweden                     1
# State of Arunachal Pradesh, India     1
# Name: count, Length: 4303, dtype: int64

# %%
split_location = df['Location'].str.split(',', expand=True)
df['City'] = split_location[0]
df['Country'] = split_location[1]
df = df.drop('Location',axis=1)

# %%
df.sample(2).T
# Out:
#                                                   3153
# Operator                                      Aeroflot  \
# Route                                              NaN
# Type                                 LET 410M turbojet
# Aboard                                            14.0
# Fatalities                                        14.0
# Ground                                             0.0
# Summary     Crashed due to engine failure on approach.
# DateTime                           1979-08-03 00:00:00
# Year                                              1979
# Month                                                8
# Day                                             Friday
# City                                         Leningrad
# Country                                           USSR
#
#                                                          3331
# Operator                                        World Airways
# Route                                 Newark, NJ - Boston, MA
# Type                             McDonnell Douglas DC-10-30CF
# Aboard                                                  212.0
# Fatalities                                                2.0
# Ground                                                    0.0
# Summary     While landing on an icy runway, the aircraft t...
# DateTime                                  1982-01-23 19:36:00
# Year                                                     1982
# Month                                                       1
# Day                                                  Saturday
# City                                            Logan Airport
# Country                                                Boston

# %%
df['Type'].sample(10)
# Out:
# 2101                    Antonov AN-24
# 5134                       Fokker 100
# 5223       Fokker F-27 Friendship 500
# 4409                     Cessna U206G
# 2605                       Beech G18S
# 4340    de Havilland Canada DHC-8-102
# 2059                   Beechcraft H50
# 3413                             PS-1
# 3824            Vickers 952F Vanguard
# 394                      Fokker F-VII
# Name: Type, dtype: object

# %%
df['Type'] = df['Type'].fillna('') 

def extract_word(row):
    words = row.split()
    if words and len(words[0]) < 3:
        return max(words, key=len)
    elif words:
        return words[0]
    else:
        return ''

df['Company'] = df['Type'].apply(extract_word)

# %%
df['Company'].sample(10)
# Out:
# 3433            Lockheed
# 315                 Avro
# 4605              Fokker
# 929              Junkers
# 4795        Aerospatiale
# 3914                CASA
# 3440              Cessna
# 3272    Dassault-Breguet
# 3786                 Let
# 546               Farman
# Name: Company, dtype: object

# %%
df['Operator'].value_counts()
# Out:
# Operator
# Aeroflot                               179
# Military - U.S. Air Force              176
# Air France                              70
# Deutsche Lufthansa                      65
# Air Taxi                                44
#                                       ...
# Military - Argentine Navy                1
# Richland Flying Service - Air Taxii      1
# Harbor Airlines - Air Taxi               1
# Aerovias Venezolanas SA (Venezuela)      1
# Strait Air                               1
# Name: count, Length: 2476, dtype: int64

# %%
df['Operator'].nunique()
# Out:
# 2476

# %%
df['Operator'] = df['Operator'].str.upper()
df['Operator'].fillna('', inplace=True)

ope_conditions = [
    df['Operator'].str.contains('MAIL|EXPRESS|TRANSPORT|SERVICE', case=False, regex=True),
    df['Operator'].str.contains('PRIVATE', case=False),
    df['Operator'].str.contains('AIR FORCE|MILITARY', case=False, regex=True)
]

flight_type_values = ['cargo', 'private', 'military']

df['Flight Type'] = np.select(ope_conditions, flight_type_values, default='passenger')

# %%
df.sample(3).T
# Out:
#                                           1152
# Operator     FRIGORIFICO COOPERATIVO LOS ANDES  \
# Route                                      NaN
# Type                       Curtiss C-46D-15-CU
# Aboard                                    27.0
# Fatalities                                27.0
# Ground                                     0.0
# Summary                                    NaN
# DateTime                   1951-09-29 00:00:00
# Year                                      1951
# Month                                        9
# Day                                   Saturday
# City                                    La Paz
# Country                                Bolivia
# Company                                Curtiss
# Flight Type                          passenger
#
#                                                           1872
# Operator                                       INDIAN AIRLINES  \
# Route                                 Madras - Nagpur - Delhi.
# Type                                     Vickers Viscount 768D
# Aboard                                                    18.0
# Fatalities                                                18.0
# Ground                                                     0.0
# Summary      Went into a steep dive and crashed into a fiel...
# DateTime                                   1963-09-11 00:00:00
# Year                                                      1963
# Month                                                        9
# Day                                                  Wednesday
# City                                                Near Patti
# Country                                                  India
# Company                                                Vickers
# Flight Type                                          passenger
#
#                                                           2037
# Operator                              CANADIAN PACIFIAIR LINES
# Route                                        Hong Kong - Tokyo
# Type                                 McDonnell Douglas DC-8-43
# Aboard                                                    72.0
# Fatalities                                                64.0
# Ground                                                     0.0
# Summary      The aircraft struck the approach lights and a ...
# DateTime                                   1966-03-04 20:15:00
# Year                                                      1966
# Month                                                        3
# Day                                                     Friday
# City                                                Near Tokyo
# Country                                                  Japan
# Company                                              McDonnell
# Flight Type                                          passenger

# %%
df['Survivors'] = df['Aboard'] - df['Fatalities']

# %%
df['Summary'] = df['Summary'].str.lower()

df['Summary'].fillna('', inplace=True)

def get_phase(summary):
    if 'landing' in summary.lower() or 'land' in summary.lower() or 'descending' in summary.lower():
        return 'While landing'
    elif 'en route' in summary.lower() or 'route' in summary.lower():
        return 'While en route'
    elif 'taking off' in summary.lower() or 'takeoff' in summary.lower():
        return 'While taking off'
    else:
        return 'unknown'

def get_cause(summary):
    if 'shot down by' in summary.lower():
        return 'War'
    elif any(keyword in summary.lower() for keyword in ['weather','icing ', 'fog', 'storm', 'lightning']):
        return 'Weather conditions'
    elif any(keyword in summary.lower() for keyword in ['pilot', 'pilot error']):
        return 'Pilot error'
    elif any(keyword in summary.lower() for keyword in ['engine', 'engine failure']):
        return 'Engine failure'
    elif any(keyword in summary.lower() for keyword in ['fire']):
        return 'Fire'
    elif any(keyword in summary.lower() for keyword in ['collided']):
        return 'Clash'
    else:
        return 'unknown'

df['Phase'] = df['Summary'].apply(get_phase)
df['Cause'] = df['Summary'].apply(get_cause)

df['%Survivors'] = (df['Survivors'] / df['Aboard']) * 100

# %%
new_column_order = ['DateTime','Year','Month','Day','City', 'Country', 'Operator', 'Type', 'Company',
                    'Route', 'Aboard', 'Fatalities', 'Ground','Survivors', 'Flight Type', 'Phase','Cause','Summary','%Survivors']
df = df[new_column_order]

# %%
df.sample(5).T
# Out:
#                                                           3292
# DateTime                                   1981-06-26 00:00:00  \
# Year                                                      1981
# Month                                                        6
# Day                                                     Friday
# City                                                 Nailstone
# Country                                                England
# Operator                                      DAN AIR SERVICES
# Type                                    Hawker Siddeley HS-748
# Company                                                 Hawker
# Route                                   London - East Midlands
# Aboard                                                     3.0
# Fatalities                                                 3.0
# Ground                                                     0.0
# Survivors                                                  0.0
# Flight Type                                              cargo
# Phase                                                  unknown
# Cause                                                  unknown
# Summary      the the right rear door  of the cargo plane de...
# %Survivors                                                 0.0
#
#                                                           381
# DateTime                                   1935-12-31 17:20:00  \
# Year                                                      1935
# Month                                                       12
# Day                                                    Tuesday
# City                                            Off Alexandria
# Country                                                  Egypt
# Operator                                      IMPERIAL AIRWAYS
# Type                                            Short Calcutta
# Company                                                  Short
# Route                                   Mirabella - Alexandria
# Aboard                                                    13.0
# Fatalities                                                12.0
# Ground                                                     0.0
# Survivors                                                  1.0
# Flight Type                                          passenger
# Phase                                                  unknown
# Cause                                                  unknown
# Summary      the aircraft ran out of fuel and crashed off a...
# %Survivors                                            7.692308
#
#                                                           3542
# DateTime                                   1985-02-22 00:00:00  \
# Year                                                      1985
# Month                                                        2
# Day                                                     Friday
# City                                                  Timbuktu
# Country                                                   Mali
# Operator                                              AIR MALI
# Type                                            Antonov AN-24V
# Company                                                Antonov
# Route                                      Tombouctou - Bamako
# Aboard                                                    51.0
# Fatalities                                                50.0
# Ground                                                     0.0
# Survivors                                                  1.0
# Flight Type                                          passenger
# Phase                                         While taking off
# Cause                                           Engine failure
# Summary      crashed after taking off. the plane was not ab...
# %Survivors                                            1.960784
#
#                                                           388
# DateTime                                   1936-03-26 00:00:00  \
# Year                                                      1936
# Month                                                        3
# Day                                                   Thursday
# City                                                   Amemeca
# Country                                                 Mexico
# Operator                                    COMPANIA DE MEXICO
# Type                                     Ford 5-AT-B Tri Motor
# Company                                                   Ford
# Route                                       Mexico - Guatemala
# Aboard                                                    14.0
# Fatalities                                                14.0
# Ground                                                     0.0
# Survivors                                                  0.0
# Flight Type                                          passenger
# Phase                                                  unknown
# Cause                                                     Fire
# Summary      crashed into mountains and caught fire.  the p...
# %Survivors                                                 0.0
#
#                                                           2309
# DateTime                                   1969-04-24 00:00:00
# Year                                                      1969
# Month                                                        4
# Day                                                   Thursday
# City                                             Near Takoradi
# Country                                                  Ghana
# Operator                                         GHANA AIRWAYS
# Type                                              Douglas DC-3
# Company                                                Douglas
# Route                                                      NaN
# Aboard                                                    33.0
# Fatalities                                                 1.0
# Ground                                                     0.0
# Survivors                                                 32.0
# Flight Type                                          passenger
# Phase                                            While landing
# Cause                                           Engine failure
# Summary      the aircraft struck high ground after engine p...
# %Survivors                                           96.969697

# %%
df.to_csv('Airplane_Crashes_LV2.csv')

# %%
df.columns
# Out:
# Index(['DateTime', 'Year', 'Month', 'Day', 'City', 'Country', 'Operator',
#        'Type', 'Company', 'Route', 'Aboard', 'Fatalities', 'Ground',
#        'Survivors', 'Flight Type', 'Phase', 'Cause', 'Summary', '%Survivors'],
#       dtype='object')

# %% [markdown]
# # Aircraft Crash New Information:
#
# - **DateTime:** date the crash
# - **Year:** Year the crash
# - **Month:** Month the crash
# - **Day:** Day the crash
# - **City:**
# - **Company:**
# - **Operator:** Airline Name (Royal air maroc,rayanair,.....)
# - **Type:** Aircraft Type (Boeing 737,Airbus A320,....)
# - **Route:** Departure - Destination
# - **Aboard:** Number of People Aboard
# - **Fatalities:** Number of Fatalities
# - **Ground:** individuals who are not on board the aircraft but are located in the vicinity of the crash site
# - **Survivors:**
# - **Flight Type:**
# - **Phase:** The phase of the accident (landing,en route,taking off)
# - **Cause:** The cause of the accident (weather condition ..  . . . .)
# - **Summary:** Brief Summary of the Case

# %%
df.head()
# Out:
#              DateTime  Year  Month        Day                City
# 0 1908-09-17 17:18:00  1908      9   Thursday           Fort Myer  \
# 1 1912-07-12 06:30:00  1912      7     Friday         AtlantiCity
# 2 1913-08-06 00:00:00  1913      8  Wednesday            Victoria
# 3 1913-09-09 18:30:00  1913      9    Tuesday  Over the North Sea
# 4 1913-10-17 10:30:00  1913     10     Friday   Near Johannisthal
#
#              Country                Operator                    Type
# 0           Virginia    MILITARY - U.S. ARMY        Wright Flyer III  \
# 1         New Jersey    MILITARY - U.S. NAVY               Dirigible
# 2   British Columbia                 PRIVATE        Curtiss seaplane
# 3               None  MILITARY - GERMAN NAVY  Zeppelin L-1 (airship)
# 4            Germany  MILITARY - GERMAN NAVY  Zeppelin L-2 (airship)
#
#      Company          Route  Aboard  Fatalities  Ground  Survivors
# 0     Wright  Demonstration     2.0         1.0     0.0        1.0  \
# 1  Dirigible    Test flight     5.0         5.0     0.0        0.0
# 2    Curtiss            NaN     1.0         1.0     0.0        0.0
# 3   Zeppelin            NaN    20.0        14.0     0.0        6.0
# 4   Zeppelin            NaN    30.0        30.0     0.0        0.0
#
#   Flight Type          Phase               Cause
# 0    military        unknown             unknown  \
# 1    military        unknown             unknown
# 2     private        unknown  Weather conditions
# 3    military  While landing  Weather conditions
# 4    military        unknown      Engine failure
#
#                                              Summary  %Survivors
# 0  during a demonstration flight, a u.s. army fly...        50.0
# 1  first u.s. dirigible akron exploded just offsh...         0.0
# 2  the first fatal airplane accident in canada oc...         0.0
# 3  the airship flew into a thunderstorm and encou...        30.0
# 4  hydrogen gas which was being vented was sucked...         0.0
